# %% [markdown]
# ## Chapter 7: Neural Networks

# %% [markdown]
# **Apply a neural network to the employee retention data we worked with in Chapter 6. Try to build this neural network so it predicts on this dataset and use accuracy and confusion matrices to evaluate performance. Is it a good model for this problem? Why or why not?**
