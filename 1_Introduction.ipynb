# %% [markdown]
# ## Basic math and Calculus Review
# #### Foundations overview for the rest of the book.

# %% [markdown]
# **Is the value 62.67838 rational or irrational? Why or why not?**

# %% [markdown]
# **Evaluate the expression: 10^7*10^-5**

# %% [markdown]
# **Evaluate the expression: 81 1/2**

# %% [markdown]
# **Evaluate the expression: 25 3/2**

# %% [markdown]
# **Assuming no payments are made, how much would a $1,000 loan be worth at 5% interest compounded monthly after 3 years?**

# %% [markdown]
# **Assuming no payments are made, how much would a $1,000 loan be worth at 5% interest compounded monthly after 3 years?**

# %% [markdown]
# **For the function f(x) = 3x^2+1 whwat is the slope at x = 3?**

# %% [markdown]
# **For the function f(x) = 3x^2+1 whwat is the area under the curve for x between 0 and 2?**
